# %%
import os
import quandl

# %%
api_key = os.environ['QUANDL_API_KEY']
quandl.ApiConfig.api_key = api_key

# %%
may = quandl.get("CME/NFK2018") # K
apr = quandl.get("CME/NFJ2018") # J
mar = quandl.get("CME/NFH2018") # H
feb = quandl.get("CME/NFG2018") # G
jan = quandl.get("CME/NFF2018") # F

# %%
jan.tail(30)
# Out:
#               Open    High     Low    Last  Change  Settle  Volume  \
# Date
# 2017-12-18  69.175  69.600  68.500  68.700   0.425  69.600    65.0
# 2017-12-19  68.800  69.225  68.800  69.000   0.625  68.975    20.0
# 2017-12-20  69.300  69.325  69.100  69.225   0.125  69.100    12.0
# 2017-12-21  69.225  70.425  69.225  70.425   0.975  70.075     9.0
# 2017-12-22     NaN  70.300     NaN  70.300     NaN  70.075     0.0
# 2017-12-26     NaN  70.225     NaN  70.225   0.075  70.150     0.0
# 2017-12-27  70.250  70.500  70.250  70.300   0.350  70.500    11.0
# 2017-12-28  70.150  70.500  70.000  70.000   0.500  70.000    46.0
# 2017-12-29  70.550  70.550  70.000  70.000   0.125  70.125    16.0
# 2018-01-02  70.025  70.075  70.025  70.075   0.100  70.025     2.0
# 2018-01-03  70.000  70.000  69.825  70.000   0.025  70.000    18.0
# 2018-01-04  69.850  69.850  69.850  69.850   0.150  69.850     4.0
# 2018-01-05     NaN     NaN     NaN     NaN     NaN  69.850     0.0
# ...
